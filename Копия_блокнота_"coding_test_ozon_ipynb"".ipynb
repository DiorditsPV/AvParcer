# %% [markdown]
# <a href="https://colab.research.google.com/github/DiorditsPV/AvParcer/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22coding_test_ozon_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Live-coding
#
# Этот ноутбук содержит в себе несколько практических задач, которые надо реализовать на языке Python. В процессе решения вы демонстрируете свой экран интервьюеру. Если вы что-то забыли, не возбраняется пользоваться вашей любимой поисковой системой при условии полной прозрачности этого процесса для интервьюера (другими словами, поиск должен проходить на том же расшаренном экране). Примерное время решения указано в условии каждой из задач.

# %% [markdown]
# # Задача 1:  алгоритмы
#
# Даны два отсортированных целочисленных списка, вам необходимо, используя только стандартные питоновские структуры данных (кортежи, списки, словари), вывести их объединение - также отсортированный список. Это шаг merge алгоритма [merge-sort](https://neerc.ifmo.ru/wiki/index.php?title=Сортировка_слиянием).
#
# > Ответ: [ 4, 5, 6, 7, 10, 10, 12, 25, 60, 80 ]

# %%
list1 = [4, 7, 10, 25]
list2 = [5, 6, 10, 12, 60, 80]

# %%
s = list()

# %%
while i > len(list1) or i > len(list2):
  i =

# %%
for i in range(max([len(list1), len(list2)])):
  if list1[i] > list2[i]:
    s.append(list2[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-af62d55d3339> in <module>
#       1 for i in range(max([len(list1), len(list2)])):
# ----> 2   if list1[i] > list2[i]:
#       3     s.append(list2[i])
#
# IndexError: list index out of range

# %% [markdown]
# # Задача 2:  графы
#
# Вам необходимо, используя только стандартные питоновские структуры данных (кортежи, списки, словари), реализовать алгоритм <a href="https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D0%B8%D1%81%D0%BA_%D0%B2_%D1%88%D0%B8%D1%80%D0%B8%D0%BD%D1%83">поиска в ширину</a> на направленном графе и с его помощью найти кратчайший путь из точки start_point в точку end_point. У вас есть код чтения графа из файла sample_graph.tsv в список ребёр, представленных элементами вида [начальная вершина, конечная вершина].
#
#
# > Путь из вершины 12 в вершину 34 для самопроверки - 12, 422, 53, 52, 107, 20, 23, 274, 34.

# %%
# загрузка графа и чтение

# !wget --no-verbose https://www.dropbox.com/s/e3vy29ciuyhe1sg/sample_graph.tsv
    
graph = []
with open('sample_graph.tsv','r') as f:
    for line in f:
        v = line.split('\t')
        graph.append([int(v[1]),int(v[0])])
graph[:3]
# Out:
# 2022-11-30 13:54:20 URL:https://uc0a0ed6ea4ee2bd889cd5473f16.dl.dropboxusercontent.com/cd/0/inline/BxvhlU7r7Ji9KSWOXjhoox2GlkqG28R8bTg7SW7e8re3n2ostWJkmJXnpsV8RTsNKO_FK_YE25AMgvbyM8t8aWB6f3d1r6jGI7tU1hAh3cP4TDEG3SoggbbygikdMGcIfntNT0Y1Ci53JK2HIOO-OxzsmlkC5lIGEzwF_wu6seu6Cg/file [672691/672691] -> "sample_graph.tsv" [1]
# [[2241, 12], [13349, 12], [41873, 12]]

# %%
[x for x in graph if x[1] == 648]
# Out:
# [[12, 648],
#  [57533, 648],
#  [668873, 648],
#  [5506992, 648],
#  [5574862, 648],
#  [5689832, 648],
#  [6877722, 648],
#  [8707552, 648],
#  [9838202, 648],
#  [13457472, 648],
#  [14248206, 648],
#  [15430979, 648],
#  [16155945, 648],
#  [16586690, 648],
#  [17686419, 648],
#  [18486967, 648],
#  [19952129, 648],
#  [21367472, 648],
#  [23423494, 648],
#  [29707496, 648],
#  [30405915, 648],
#  [33995786, 648],
#  [35487155, 648],
#  [36270166, 648],
#  [53102033, 648],
#  [57366477, 648]]

# %%
def to_dict():
  edges = dict()
  for start, end in graph:
    if start in edges:
      edges[int(start)].append(int(end))
    else:
      edges[int(start)] = list()
      edges[int(start)].append(int(end))
  return edges

edges = to_dict()

# %%
{k:v for k,v in edges.items() if len(v)>2}
# Out:
# {11837022: [12, 448, 541],
#  18887105: [12, 52, 291],
#  21072866: [12, 20, 291],
#  36410576: [12, 20, 291],
#  52041136: [12, 13, 20],
#  9142892: [13, 414, 422],
#  9598762: [13, 15, 246, 544],
#  14559760: [14, 59, 288],
#  14: [15, 126, 582],
#  107: [15, 20, 586],
#  19923995: [15, 23, 57],
#  23: [16, 38, 274],
#  19788155: [17, 194, 586],
#  26468557: [20, 94, 637],
#  50621945: [20, 291, 586],
#  6712022: [21, 58, 60],
#  19753983: [21, 255, 259],
#  20: [23, 87, 292, 295],
#  18234522: [23, 194, 509],
#  18662758: [23, 150, 422],
#  53: [31, 52, 57, 150, 187, 292, 652],
#  16027455: [34, 432, 681],
#  16227030: [47, 94, 348],
#  16602650: [53, 150, 521],
#  21494147: [53, 60, 288],
#  13342022: [57, 107, 380, 388],
#  35256698: [57, 277, 344],
#  46610113: [58, 126, 414],
#  4951921: [60, 246, 528],
#  14206015: [60, 259, 448],
#  15458708: [64, 292, 294, 295],
#  16012577: [67, 150, 441],
#  22967671: [87, 292, 418],
#  12: [126, 380, 422, 648],
# ...

# %%
# Out:
# []

# %%
def solution(start, end, q=list(), ):
  nodes = edges.get(start, [])
  q.extend(nodes)

  if not nodes: 
    # print(f"Nodes of {start:<4} -- {str(nodes):<35}" + f"queue: {str(q)}")
    solution(q.pop(0), end, q)
  
  
  if end in nodes: 
    print("done!")
    print(f"Nodes of {start:<4} -- {str(nodes):<35}" + f"queue: {str(q)}")
    return 
  
  elif nodes : 
    
    print(f"Nodes of {start:<4} -- {str(no des):<35}" + f"queue: {str(q)}")
    solution(q.pop(0), end, q)


start_point = 12
end_point = 34
solution(start_point, end_point)
# Out:
# Nodes of 12   -- [126, 380, 422, 648]               queue: [126, 380, 422, 648]
# Nodes of 422  -- [53]                               queue: [648, 53]
# Nodes of 53   -- [31, 52, 57, 150, 187, 292, 652]   queue: [31, 52, 57, 150, 187, 292, 652]
# Nodes of 31   -- [13]                               queue: [52, 57, 150, 187, 292, 652, 13]
# Nodes of 52   -- [107]                              queue: [57, 150, 187, 292, 652, 13, 107]
# Nodes of 107  -- [15, 20, 586]                      queue: [15, 20, 586]
# Nodes of 20   -- [23, 87, 292, 295]                 queue: [586, 23, 87, 292, 295]
# Nodes of 586  -- [107]                              queue: [23, 87, 292, 295, 107]
# Nodes of 23   -- [16, 38, 274]                      queue: [87, 292, 295, 107, 16, 38, 274]
# Nodes of 87   -- [64]                               queue: [292, 295, 107, 16, 38, 274, 64]
# Nodes of 107  -- [15, 20, 586]                      queue: [16, 38, 274, 64, 15, 20, 586]
# done!
# ...

# %%
def solution(start, end, visited=set()):
  nodes = edges[start]
  for i, node in enumerate(nodes):
    
    if node == end:
      return visited
    elif i == len(nodes):
      visited.add(node)
      nodes = edges[start]
    else:
      visited.add(node)

# %%
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-102-2367eb699c50> in <module>
#       1 start_point = 12
#       2 end_point = 34
# ----> 3 solution(start_point, end_point)
#
# <ipython-input-101-8966514559dd> in solution(start, end, visited)
#       1 def solution(start, end, visited=set()):
#       2   if start in edges: nodes = edges[start]
# ----> 3   for i, node in enumerate(nodes):
#       4     print(nodes)
#       5     if node == end:
#
# UnboundLocalError: local variable 'nodes' referenced before assignment

# %%
#    1
#   2 3
# 55 66 77

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# # Задача 2: SQL
# Необходимо используя SQL ответить на вопросы ниже.

# %%
# !pip install pyspark
# !pip install -U -q PyDrive
# !apt install openjdk-8-jdk-headless -qq
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

# %%
import pyspark
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf, SQLContext

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
conf = SparkConf().set("spark.ui.port", "4050")
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()
sql = SQLContext(sc)

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
get_ipython().system_raw('./ngrok http 4050 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
id='1kUIrskM0zNH8u71G9M1BkHjRQYxvgAvh'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('data.zip')
# !unzip data.zip

# %% [markdown]
# ![image2022-2-8_16-15-37.png](data:image/png;base64,...)

# %%
sql.read.csv('data/regions.csv', header=True, sep='\t').registerTempTable('regions')
sql.read.csv('data/departments.csv', header=True, sep='\t').registerTempTable('departments')
sql.read.csv('data/jobs.csv', header=True, sep='\t').registerTempTable('jobs')
sql.read.csv('data/locations.csv', header=True, sep='\t').registerTempTable('locations')
sql.read.csv('data/country.csv', header=True, sep='\t').registerTempTable('country')
sql.read.csv('data/employees.csv', header=True, sep='\t').registerTempTable('employees')
sql.read.csv('data/job_history.csv', header=True, sep='\t').registerTempTable('job_history')

# %% [markdown]
# Кто получает больше всего? Кто меньше всего?

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Выведете топ 5 по зарплате.

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Сколько всего регионов? Сколько работников в каждом регионе?

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Выведете всех работников которые живут в Europe

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Укажите самую высокооплачиваемою должность.

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Выведете всех работников связанных с ИТ. Выведете их менеджеров.

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Выведете всех сотрудников которые меняли работу (должность), отобразите списком какие job_id у них были.

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Выведете уникальные телефонные номера.

# %%
# 
# Ваш код здесь
#

# %% [markdown]
# Есть ли сотрудники с одинаковыми фамилиями и сколько их.

# %%
# 
# Ваш код здесь
#
